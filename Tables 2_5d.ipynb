# %%
import numpy as np
import pandas as pd
import re
import os
from table import Table

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
tabn = '330.40'
tab = Table('100tables/tabn' + tabn + '.xls', '2019')

# %%
tab.table_info
# Out:
#   digest_table_id digest_table_year digest_table_sub_id  \
# 0          330.40              2019                   A
# 1          330.40              2019                   B
#
#      digest_table_sub_title  \
# 0           Current dollars
# 1  Constant 2018-19 dollars
#
#                          digest_table_sub_title_note has_SE location_in  \
# 0                                                     FALSE       Title
# 1  Constant dollars based on the Consumer Price I...  FALSE       Title
#
#   year_in year       location location_info  \
# 0  Column       United States
# 1  Column       United States
#
#                                          table_title headnote  \
# 0  Average total cost of attendance for first-tim...
# 1  Average total cost of attendance for first-tim...
#
#                                            stub_head  \
# 0  Level of institution, living arrangement, and ...
# 1  Level of institution, living arrangement, and ...
#
# ...

# %%
# col = tab.table_info["digest_table_sub_title"]
# refs = col.str.extract(r"\\([0-9]),?([0-9])?\\")
# refs = refs.replace(tab.footnotes)
# refs = refs.fillna("")
# s = refs[0] + ":::" + refs[1]
# s = s.replace(r":::$", "", regex=True)
# tab.table_info.insert(4,'digest_table_sub_title_note',s)
# tab.table_info.replace(r"\\([0-9]),?([0-9])?\\", "", regex=True)

# %%
tab.col_info
# Out:
#    digest_table_id digest_table_year digest_table_sub_id  \
# 0           330.40              2019                   A
# 1           330.40              2019                   A
# 2           330.40              2019                   A
# 3           330.40              2019                   A
# 4           330.40              2019                   A
# 5           330.40              2019                   A
# 6           330.40              2019                   A
# 7           330.40              2019                   A
# 8           330.40              2019                   A
# 9           330.40              2019                   A
# 10          330.40              2019                   A
# 11          330.40              2019                   A
# 12          330.40              2019                   A
# 13          330.40              2019                   A
# 14          330.40              2019                   A
# ...

# %%
tab.row_info
# Out:
#    digest_table_id digest_table_year digest_table_sub_id  \
# 8           330.40              2019                   A
# 9           330.40              2019                   A
# 10          330.40              2019                   A
# 12          330.40              2019                   A
# 13          330.40              2019                   A
# 16          330.40              2019                   A
# 17          330.40              2019                   A
# 19          330.40              2019                   A
# 21          330.40              2019                   A
# 22          330.40              2019                   A
# 25          330.40              2019                   A
# 26          330.40              2019                   A
# 27          330.40              2019                   A
# 29          330.40              2019                   A
# 30          330.40              2019                   A
# ...

# %%
tab.cell_info
# Out:
# Empty DataFrame
# Columns: [digest_table_id, digest_table_year, digest_table_sub_id, digest_table_sub_title, is_standard_error, is_dollar, format_string, row_index, column_index, cell_note]
# Index: []
