# %%
import numpy as np
import pandas as pd
import re
import os
from table import Table

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
tabn = '330.30'
tab = Table('100tables/tabn' + tabn + '.xls', '2019')

# %%
tab.table_info
# Out:
#   digest_table_id digest_table_year digest_table_sub_id  \
# 0          330.30              2019                   A
#
#   digest_table_sub_title digest_table_sub_title_note has_SE location_in  \
# 0                                                     FALSE       Title
#
#   year_in year       location location_type  \
# 0     Row       United States        Region
#
#                                          table_title headnote  \
# 0  Average undergraduate tuition, fees, room, and...
#
#                                     stub_head  \
# 0  Control and level of institution, and year
#
#                                         general_note  \
# 0  Data are for the entire academic year and are ...
#
#                                          source_note  \
# 0  U.S. Department of Education, National Center ...
#
#                             last_prepared
# 0  This table was prepared December 2019.

# %%
tab.col_info
# Out:
#    digest_table_id digest_table_year digest_table_sub_id  \
# 0           330.30              2019                   A
# 1           330.30              2019                   A
# 2           330.30              2019                   A
# 3           330.30              2019                   A
# 4           330.30              2019                   A
# 5           330.30              2019                   A
# 6           330.30              2019                   A
# 7           330.30              2019                   A
# 8           330.30              2019                   A
# 9           330.30              2019                   A
# 10          330.30              2019                   A
# 11          330.30              2019                   A
# 12          330.30              2019                   A
# 13          330.30              2019                   A
# 14          330.30              2019                   A
#
# ...

# %%
tab.row_info
# Out:
#    digest_table_id digest_table_year digest_table_sub_id  \
# 6           330.30              2019                   A
# 7           330.30              2019                   A
# 8           330.30              2019                   A
# 9           330.30              2019                   A
# 10          330.30              2019                   A
# 11          330.30              2019                   A
# 13          330.30              2019                   A
# 14          330.30              2019                   A
# 15          330.30              2019                   A
# 16          330.30              2019                   A
# 17          330.30              2019                   A
# 18          330.30              2019                   A
# 20          330.30              2019                   A
# 21          330.30              2019                   A
# 22          330.30              2019                   A
# ...

# %%
# tab.row_info.loc[13:18, 'row_level_3'] = tab.row_info.loc[13:18, 'row_level_2'].values
# tab.row_info.loc[20:25, 'row_level_3'] = tab.row_info.loc[20:25, 'row_level_2'].values
# tab.row_info.loc[34:39, 'row_level_3'] = tab.row_info.loc[34:39, 'row_level_2'].values
# tab.row_info.loc[41:46, 'row_level_3'] = tab.row_info.loc[41:46, 'row_level_2'].values
# tab.row_info.loc[55:60, 'row_level_3'] = tab.row_info.loc[41:46, 'row_level_2'].values
# tab.row_info.loc[62:67, 'row_level_3'] = tab.row_info.loc[62:67, 'row_level_2'].values

# tab.row_info.loc[13:18, 'row_level_2'] = 'Public 4-year'
# tab.row_info.loc[20:25, 'row_level_2'] = 'Public 2-year'
# tab.row_info.loc[34:39, 'row_level_2'] = 'Nonprofit 4-year'
# tab.row_info.loc[41:46, 'row_level_2'] = 'Nonprofit 2-year'
# tab.row_info.loc[55:60, 'row_level_2'] = 'For-profit 4-year'
# tab.row_info.loc[62:67, 'row_level_2'] = 'For-profit 2-year'

# tab.row_info.loc[13:18, 'row_ref_note_2'] = 'Average undergraduate tuition and fees are based on in-state students only.'
# tab.row_info.loc[20:25, 'row_ref_note_2'] = 'Average undergraduate tuition and fees are based on in-state students only.'


# tab.row_info

# %%
tab.cell_info
# Out:
# Empty DataFrame
# Columns: [digest_table_id, digest_table_year, digest_table_sub_id, digest_table_sub_title, is_standard_error, is_dollar, format_string, row_index, column_index, cell_note]
# Index: []

# %%
tab.write_xlsx()
