# %%
import numpy as np
import pandas as pd
import re
from table import Table

# %%
tab203_10 = Table("tables/tabn203.10.xls", "2019")

# %%
tab203_10.table_info.T
# Out:
#                    0                                                  1
# 0    digest_table_id                                             203.10
# 1  digest_table_year                                               2019
# 2        table_title  Enrollment in public elementary and secondary ...
# 3           headnote                                     [In thousands]
# 4          stub_head                                               Year
# 5       general_note  Due to changes in reporting and imputation pra...
# 6        source_note  U.S. Department of Education, National Center ...
# 7      last_prepared             This table was prepared December 2019.

# %%
tab203_10.table_info[2].values
# Out:
# array(['table_title',
#        'Enrollment in public elementary and secondary schools, by level and grade: Selected years, fall 1980 through fall 2029'],
#       dtype=object)

# %%
tab203_10.col_info
# Out:
#    digest_table_id digest_table_year column_index column_level_1  \
# 0           203.10              2019            A     All grades
# 1           203.10              2019            B     Elementary
# 2           203.10              2019            C     Elementary
# 3           203.10              2019            D     Elementary
# 4           203.10              2019            E     Elementary
# 5           203.10              2019            F     Elementary
# 6           203.10              2019            G     Elementary
# 7           203.10              2019            H     Elementary
# 8           203.10              2019            I     Elementary
# 9           203.10              2019            J     Elementary
# 10          203.10              2019            K     Elementary
# 11          203.10              2019            L     Elementary
# 12          203.10              2019            M     Elementary
# ...

# %%
tab203_50 = Table("tables/tabn203.50.xls", "2019")

# %%
tab203_50.table_info.T
# Out:
#                    0                                                  1
# 0    digest_table_id                                             203.50
# 1  digest_table_year                                               2019
# 2        table_title  Enrollment and percentage distribution of enro...
# 3           headnote
# 4          stub_head                                    Region and year
# 5       general_note  Race categories exclude persons of Hispanic et...
# 6        source_note  U.S. Department of Education, National Center ...
# 7      last_prepared             This table was prepared December 2019.

# %%
tab203_50.col_info
# Out:
#    digest_table_id digest_table_year column_index             column_level_1  \
# 0           203.50              2019            A  Enrollment (in thousands)
# 1           203.50              2019            B  Enrollment (in thousands)
# 2           203.50              2019            C  Enrollment (in thousands)
# 3           203.50              2019            D  Enrollment (in thousands)
# 4           203.50              2019            E  Enrollment (in thousands)
# 5           203.50              2019            F  Enrollment (in thousands)
# 6           203.50              2019            G  Enrollment (in thousands)
# 7           203.50              2019            H  Enrollment (in thousands)
# 8           203.50              2019            I    Percentage distribution
# 9           203.50              2019            J    Percentage distribution
# 10          203.50              2019            K    Percentage distribution
# ...

# %%
tab236_30 = Table("tables/tabn236.30.xls", "2019")

# %%
tab236_30.table_info.T
# Out:
#                    0                                                  1
# 0    digest_table_id                                             236.30
# 1  digest_table_year                                               2019
# 2        table_title  Total expenditures for public elementary and s...
# 3           headnote                  [In thousands of current dollars]
# 4          stub_head                              State or jurisdiction
# 5       general_note  Excludes expenditures for state education agen...
# 6        source_note  U.S. Department of Education, National Center ...
# 7      last_prepared               This table was prepared August 2019.

# %%
tab236_30.col_info
# Out:
#    digest_table_id digest_table_year column_index        column_level_1  \
# 0           236.30              2019            A  Total expenditures
# 1           236.30              2019            B  Total expenditures
# 2           236.30              2019            C  Total expenditures
# 3           236.30              2019            D  Total expenditures
# 4           236.30              2019            E  Total expenditures
# 5           236.30              2019            F  Total expenditures
# 6           236.30              2019            G  Total expenditures
# 7           236.30              2019            H  Total expenditures
# 8           236.30              2019            I  Total expenditures
# 9           236.30              2019            J  Total expenditures
# 10          236.30              2019            K  Total expenditures
# 11          236.30              2019            L  Total expenditures
# ...

# %%
tab204_10 = Table("tables/tabn204.10.xls", "2019")

# %%
tab204_10.table_info.T
# Out:
#                    0                                                  1
# 0    digest_table_id                                             204.10
# 1  digest_table_year                                               2019
# 2        table_title  Number and percentage of public school student...
# 3           headnote
# 4          stub_head                                              State
# 5       general_note  The National School Lunch Program (NSLP) is a ...
# 6        source_note  U.S. Department of Education, National Center ...
# 7      last_prepared             This table was prepared February 2020.

# %%
tab204_10.table_info.iloc[1,2]
# Out:
# 'Number and percentage of public school students eligible for free or reduced-price lunch, by state: Selected years, 2000-01 through 2017-18'

# %%
tab204_10.table_info.iloc[1,5]
# Out:
# 'The National School Lunch Program (NSLP) is a federally assisted meal program. Table reflects counts of students enrolled in all schools for which both enrollment data and free/reduced-price lunch eligibility data were reported. Data for 2016-17 and 2017-18 include students whose NSLP eligibility has been determined through direct certification.'

# %%
tab204_10.table_info.iloc[1,6]
# Out:
# 'U.S. Department of Education, National Center for Education Statistics, Common Core of Data (CCD), "Public Elementary/Secondary School Universe Survey," 2000-01, 2010-11, 2016-17, and 2017-18.'

# %%
tab204_10.col_info
# Out:
#    digest_table_id digest_table_year column_index  \
# 0           204.10              2019            A
# 1           204.10              2019            B
# 2           204.10              2019            C
# 3           204.10              2019            D
# 4           204.10              2019            E
# 5           204.10              2019            F
# 6           204.10              2019            G
# 7           204.10              2019            H
# 8           204.10              2019            I
# 9           204.10              2019            J
# 10          204.10              2019            K
# 11          204.10              2019            L
#
#                                        column_level_1 column_ref_note_1  \
# 0                         Number of students enrolled
# 1                         Number of students enrolled
# 2                         Number of students enrolled
# 3                         Number of students enrolled
# ...

# %% [markdown]
# # 204.27

# %%
tab204_27 = Table("tables/tabn204.27.xls", "2019")

# %%
tab204_27.table_info.T
# Out:
#                    0                                                  1
# 0    digest_table_id                                             204.27
# 1  digest_table_year                                               2019
# 2        table_title  English language learner (ELL) students enroll...
# 3           headnote
# 4          stub_head  Home language, grade, and selected student cha...
# 5       general_note  Includes all students identified as English la...
# 6        source_note  U.S. Department of Education, National Center ...
# 7      last_prepared            This table was prepared September 2019.

# %%
tab204_27.table_info.iloc[1,4]
# Out:
# 'Home language, grade, and selected student characteristic'

# %%
tab204_27.col_info
# Out:
#    digest_table_id digest_table_year column_index  \
# 0           204.27              2019            A
# 1           204.27              2019            B
# 2           204.27              2019            C
# 3           204.27              2019            D
# 4           204.27              2019            E
# 5           204.27              2019            F
# 6           204.27              2019            G
# 7           204.27              2019            H
# 8           204.27              2019            I
# 9           204.27              2019            J
# 10          204.27              2019            K
# 11          204.27              2019            L
# 12          204.27              2019            M
# 13          204.27              2019            N
# 14          204.27              2019            O
# 15          204.27              2019            P
# 16          204.27              2019            Q
# 17          204.27              2019            R
# ...

# %% [markdown]
# # 213.10

# %%
filename = "tables/tabn213.10.xls"
year = "2019"
tab4 = Table(filename, year)

# %%
filename = "tables/tabn215.10.xls"
year = "2019"
tab5 = Table(filename, year)

# %%
tab5.table_info.T
# Out:
#                    0                                                  1
# 0    digest_table_id                                             215.10
# 1  digest_table_year                                               2019
# 2        table_title  Selected statistics on enrollment, teachers, d...
# 3           headnote
# 4          stub_head                                   Name of district
# 5       general_note  Total enrollment, staff, and teacher data in t...
# 6        source_note  U.S. Department of Education, National Center ...
# 7      last_prepared                  This table was prepared May 2019.

# %%
tab5.table_info.loc[1,2]
# Out:
# 'Selected statistics on enrollment, teachers, dropouts, and graduates in public school districts enrolling more than 15,000 students: Selected years, 1990 through 2016'

# %%
tab5.table_info.loc[1,5]
# Out:
# 'Total enrollment, staff, and teacher data in this table reflect totals reported by school districts and may differ from data derived from summing school-level data to school district aggregates. Includes only regular school districts. Regular districts exclude regional education service agencies and supervisory union administrative centers, state-operated agencies, federally operated agencies, and other types of local education agencies, such as independent charter schools. ISD = independent school district. CISD = consolidated independent school district. CUSD = community unit school district. Race categories exclude persons of Hispanic ethnicity. Detail may not sum to totals because of rounding.'

# %%
tab5.table_info.loc[1,6]
# Out:
# 'U.S. Department of Education, National Center for Education Statistics, Common Core of Data (CCD), "Public Elementary/Secondary School Universe Survey," 2016-17; "Local Education Agency Universe Survey," 1990-91, 2000-01, 2010-11, and 2016-17; and Regulatory Adjusted Cohort Graduation Rates (ACGR), 2010-11 through 2016-17, retrieved May 9, 2019, from https://www2.ed.gov/about/inits/ed/edfacts/data-files/index.html.'

# %%
tab5.col_info
# Out:
#    digest_table_id digest_table_year column_index  \
# 0           215.10              2019            A
# 1           215.10              2019            B
# 2           215.10              2019            C
# 3           215.10              2019            D
# 4           215.10              2019            E
# 5           215.10              2019            F
# 6           215.10              2019            G
# 7           215.10              2019            H
# 8           215.10              2019            I
# 9           215.10              2019            J
# 10          215.10              2019            K
# 11          215.10              2019            L
# 12          215.10              2019            M
# 13          215.10              2019            N
# 14          215.10              2019            O
# 15          215.10              2019            P
# 16          215.10              2019            Q
# 17          215.10              2019            R
# ...

# %%
filename = "tables/tabn217.10.xls"
year = "2019"
tab6 = Table(filename, year)

# %%
tab6.table_info.T
# Out:
#                    0                                                  1
# 0    digest_table_id                                             217.10
# 1  digest_table_year                                               2019
# 2        table_title  Functional age of public schools' main instruc...
# 3           headnote            [Standard errors appear in parentheses]
# 4          stub_head  Functional age of main instructional building;...
# 5       general_note  Detail may not sum to totals because of rounding.
# 6        source_note  U.S. Department of Education, National Center ...
# 7      last_prepared                 This table was prepared June 2014.

# %%
tab6.col_info
# Out:
#    digest_table_id digest_table_year column_index  \
# 0           217.10              2019            A
# 1           217.10              2019            B
# 2           217.10              2019            C
# 3           217.10              2019            D
# 4           217.10              2019            E
# 5           217.10              2019            F
# 6           217.10              2019            G
# 7           217.10              2019            H
# 8           217.10              2019            I
# 9           217.10              2019            J
# 10          217.10              2019            K
# 11          217.10              2019            L
#
#                                        column_level_1  \
# 0                                  All public schools
# 1                                 Instructional level
# 2                                 Instructional level
# 3                                 Instructional level
# ...

# %%
tab6.raw_df
# Out:
#                                                    0                       1   \
# 0   Table 217.10. Functional age of public schools...                     NaN
# 1             [Standard errors appear in parentheses]                     NaN
# 2   Functional age of main instructional building;...   All public schools\1\
# 3                                                 NaN                     NaN
# 4                                                   1                       2
# ..                                                ...                     ...
# 61  \5\Based on schools with the specified environ...                     NaN
# 62  \6\Based on the 31 percent of public schools w...                     NaN
# 63  \7\Based on schools with the specified environ...                     NaN
# 64  NOTE: Detail may not sum to totals because of ...                     NaN
# 65  SOURCE: U.S. Department of Education, National...                     NaN
#
# ...

# %% [markdown]
# Potentially need to implement the better solution that gets rid of empty cols in raw_df and uses the number of cols in raw_df rather than sheet.ncols

# %%
filename = "tables/tabn217.15.xls"
year = "2019"
tab7 = Table(filename, year)

# %%
tab7.table_info.T
# Out:
#                    0                                                  1
# 0    digest_table_id                                             217.15
# 1  digest_table_year                                               2019
# 2        table_title  Percentage of public schools with plans for ma...
# 3           headnote            [Standard errors appear in parentheses]
# 4          stub_head  Type of system or feature and main reason for ...
# 5       general_note  Percentage of schools with major repair, renov...
# 6        source_note  U.S. Department of Education, National Center ...
# 7      last_prepared                This table was prepared April 2014.

# %%
tab7.table_info.T.loc[2,1]
# Out:
# 'Percentage of public schools with plans for major repair, renovation, or replacement of building systems or features in the next 2 years and percentage distribution of schools with such plans, by selected school characteristics, type of system or feature, and main reason for the plans: 2012–13'

# %%
tab7.col_info
# Out:
#    digest_table_id digest_table_year column_index  \
# 0           217.15              2019            A
# 1           217.15              2019            B
# 2           217.15              2019            C
# 3           217.15              2019            D
# 4           217.15              2019            E
# 5           217.15              2019            F
# 6           217.15              2019            G
# 7           217.15              2019            H
# 8           217.15              2019            I
# 9           217.15              2019            J
# 10          217.15              2019            K
# 11          217.15              2019            L
#
#                                        column_level_1 column_ref_note_1  \
# 0                                  All public schools
# 1                                 Instructional level
# 2                                 Instructional level
# 3                                 Instructional level
# ...

# %%
filename = "tables/tabn219.70.xls"
year = "2019"
tab8 = Table(filename, year)

# %%
tab8.table_info.T
# Out:
#                    0                                                  1
# 0    digest_table_id                                             219.70
# 1  digest_table_year                                               2019
# 2        table_title  Percentage of high school dropouts among perso...
# 3           headnote            [Standard errors appear in parentheses]
# 4          stub_head                                               Year
# 5       general_note  Status dropouts are 16- to 24-year-olds who ar...
# 6        source_note  U.S. Department of Commerce, Census Bureau, Cu...
# 7      last_prepared             This table was prepared November 2019.

# %%
tab8.col_info
# Out:
#    digest_table_id digest_table_year column_index column_level_1  \
# 0           219.70              2019            A          Total
# 1           219.70              2019            B          Total
# 2           219.70              2019            C          Total
# 3           219.70              2019            D          Total
# 4           219.70              2019            E           Male
# 5           219.70              2019            F           Male
# 6           219.70              2019            G           Male
# 7           219.70              2019            H           Male
# 8           219.70              2019            I         Female
# 9           219.70              2019            J         Female
# 10          219.70              2019            K         Female
# 11          219.70              2019            L         Female
#
#    column_ref_note_1           column_level_2  \
# 0                     All races/ ethnic-ities
# ...

# %%
filename = "tables/tabn318.45.xls"
year = "2019"
tab9 = Table(filename, year)

# %%
tab9.table_info.T
# Out:
#                    0                                                  1
# 0    digest_table_id                                             318.45
# 1  digest_table_year                                               2019
# 2        table_title  Number and percentage distribution of science,...
# 3           headnote
# 4          stub_head                                       Sex and year
# 5       general_note  Data are for postsecondary institutions partic...
# 6        source_note  U.S. Department of Education, National Center ...
# 7      last_prepared              This table was prepared October 2019.

# %%
tab9.col_info
# Out:
#    digest_table_id digest_table_year column_index  \
# 0           318.45              2019            A
# 1           318.45              2019            B
# 2           318.45              2019            C
# 3           318.45              2019            D
# 4           318.45              2019            E
# 5           318.45              2019            F
# 6           318.45              2019            G
# 7           318.45              2019            H
# 8           318.45              2019            I
# 9           318.45              2019            J
# 10          318.45              2019            K
# 11          318.45              2019            L
# 12          318.45              2019            M
# 13          318.45              2019            N
# 14          318.45              2019            O
# 15          318.45              2019            P
# 16          318.45              2019            Q
# 17          318.45              2019            R
# ...
