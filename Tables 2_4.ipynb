# %%
import numpy as np
import pandas as pd
import re
import os
from table import Table

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
tabn = '203.10'
tab = Table('100tables/tabn' + tabn + '.xls', '2019')

# %%
tab.table_info
# Out:
#   digest_table_id digest_table_year digest_table_sub_id  \
# 0          203.10              2019                   A
# 1          203.10              2019                   B
#
#   digest_table_sub_title has_SE location_in year_in year       location  \
# 0                         FALSE       Title     Row       United States
# 1              Projected  FALSE       Title     Row       United States
#
#   Location_info                                        table_title  \
# 0                Enrollment in public elementary and secondary ...
# 1                Enrollment in public elementary and secondary ...
#
#          headnote stub_head  \
# 0  [In thousands]      Year
# 1  [In thousands]      Year
#
#                                         general_note  \
# 0  Due to changes in reporting and imputation pra...
# 1  Due to changes in reporting and imputation pra...
#
#                                          source_note  \
# 0  U.S. Department of Education, National Center ...
# ...

# %%
tab.col_info
# Out:
#    digest_table_id digest_table_year digest_table_sub_id  \
# 0           203.10              2019                   A
# 1           203.10              2019                   A
# 2           203.10              2019                   A
# 3           203.10              2019                   A
# 4           203.10              2019                   A
# 5           203.10              2019                   A
# 6           203.10              2019                   A
# 7           203.10              2019                   A
# 8           203.10              2019                   A
# 9           203.10              2019                   A
# 10          203.10              2019                   A
# 11          203.10              2019                   A
# 12          203.10              2019                   A
# 13          203.10              2019                   A
# 14          203.10              2019                   A
# ...

# %%
tab.col_info['column_level_2'].values
# Out:
# array(['', 'Total', 'Prekindergarten', 'Kindergarten', '1st grade',
#        '2nd grade', '3rd grade', '4th grade', '5th grade', '6th grade',
#        '7th grade', '8th grade', 'Ungraded', 'Total', '9th grade',
#        '10th grade', '11th grade', '12th grade', 'Ungraded', '', 'Total',
#        'Prekindergarten', 'Kindergarten', '1st grade', '2nd grade',
#        '3rd grade', '4th grade', '5th grade', '6th grade', '7th grade',
#        '8th grade', 'Ungraded', 'Total', '9th grade', '10th grade',
#        '11th grade', '12th grade', 'Ungraded'], dtype=object)

# %%
tab.row_info
# Out:
#    digest_table_id digest_table_year digest_table_sub_id  \
# 5           203.10              2019                   A
# 6           203.10              2019                   A
# 7           203.10              2019                   A
# 8           203.10              2019                   A
# 9           203.10              2019                   A
# 10          203.10              2019                   A
# 11          203.10              2019                   A
# 12          203.10              2019                   A
# 13          203.10              2019                   A
# 14          203.10              2019                   A
# 15          203.10              2019                   A
# 16          203.10              2019                   A
# 17          203.10              2019                   A
# 18          203.10              2019                   A
# 19          203.10              2019                   A
# ...

# %%
tab.cell_info
# Out:
# Empty DataFrame
# Columns: [digest_table_id, digest_table_year, digest_table_sub_id, digest_table_sub_title, row_index, column_index, cell_note]
# Index: []

# %%
data = pd.DataFrame({'A': ['the admini-stration', 'Baccalaure-ate', 'degrees'],'B': ['abc', 'bar', 'xyz']})

# %%
data
# Out:
#                      A    B
# 0  the admini-stration  abc
# 1       Baccalaure-ate  bar
# 2              degrees  xyz

# %%
df = pd.read_csv("scraping_dictionary.csv")

# %%
dic = dict(zip(df['hyphenated'], df['corrected']))

# %%
data.replace(dic, regex=True)
# Out:
#                     A    B
# 0  the administration  abc
# 1       Baccalaureate  bar
# 2             degrees  xyz

# %%
dic
# Out:
# {'admini-stration': 'administration',
#  'adminis-tration': 'administration',
#  'adminis-trative': 'administrative',
#  'Alterna-tive': 'Alternative',
#  'appro-priations': 'appropriations',
#  "Assoc-iate's": "Associate's",
#  'Bac-calaur-eate': 'Baccalaureate',
#  'Baccalaure-ate': 'Baccalaureate',
#  "Bache-lor's": "Bachelor's",
#  'Com-bined': 'Combined',
#  'con-trol': 'control',
#  'coordi-nators': 'coordinators',
#  'counsel-ors': 'counselors',
#  'de-grees': 'degrees',
#  'Dis-tant': 'Distant',
#  'dis-tricts': 'districts',
#  "Doc-tor's": "Doctor's",
#  'Doc-toral': 'Doctoral',
#  'educa-tion': 'education',
#  'Elemen-tary': 'Elementary',
#  'enroll-ment': 'enrollment',
#  'Enter-prise': 'Enterprise',
#  'enter-prises': 'enterprises',
#  'ethnic-ities': 'ethnicities',
#  'expen-ditures': 'expenditures',
#  'expendi-ture': 'expenditure ',
#  'His-panic': 'Hispanic',
#  'In-terest': 'Interest',
#  'Indepen-dent': 'Independent',
#  'insti-tutions': 'institutions',
# ...
