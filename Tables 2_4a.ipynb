# %%
import numpy as np
import pandas as pd
import re
import os
from table import Table

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
tabn = '203.50'
tab = Table('100tables/tabn' + tabn + '.xls', '2019')

# %%
tab.table_info
# Out:
#   digest_table_id digest_table_year digest_table_sub_id  \
# 0          203.50              2019                   A
#
#   digest_table_sub_title has_SE location_in year_in year       location  \
# 0                         FALSE       Title     Row       United States
#
#   Location_info                                        table_title headnote  \
# 0                Enrollment and percentage distribution of enro...
#
#          stub_head                                       general_note  \
# 0  Region and year  Race categories exclude persons of Hispanic et...
#
#                                          source_note  \
# 0  U.S. Department of Education, National Center ...
#
#                             last_prepared
# 0  This table was prepared December 2019.

# %%
tab.col_info
# Out:
#    digest_table_id digest_table_year digest_table_sub_id  \
# 0           203.50              2019                   A
# 1           203.50              2019                   A
# 2           203.50              2019                   A
# 3           203.50              2019                   A
# 4           203.50              2019                   A
# 5           203.50              2019                   A
# 6           203.50              2019                   A
# 7           203.50              2019                   A
# 8           203.50              2019                   A
# 9           203.50              2019                   A
# 10          203.50              2019                   A
# 11          203.50              2019                   A
# 12          203.50              2019                   A
# 13          203.50              2019                   A
# 14          203.50              2019                   A
# ...

# %%
tab.row_info
# Out:
#    digest_table_id digest_table_year digest_table_sub_id  \
# 5           203.50              2019                   A
# 6           203.50              2019                   A
# 7           203.50              2019                   A
# 8           203.50              2019                   A
# 9           203.50              2019                   A
# 10          203.50              2019                   A
# 11          203.50              2019                   A
# 12          203.50              2019                   A
# 13          203.50              2019                   A
# 14          203.50              2019                   A
# 15          203.50              2019                   A
# 16          203.50              2019                   A
# 17          203.50              2019                   A
# 18          203.50              2019                   A
# 19          203.50              2019                   A
# ...

# %%
tab.row_info.query("row_index == '18'")['E']
# Out:
# 22    2571.069
# Name: E, dtype: object

# %%
tab.raw_df.loc[22,5]
# Out:
# 2571.069

# %%
tab.raw_df.astype(str).loc[22,5]
# Out:
# '2571.069'

# %%
tab.cell_info
# Out:
#     digest_table_id digest_table_year digest_table_sub_id  \
# 0            203.50              2019                   A
# 1            203.50              2019                   A
# 2            203.50              2019                   A
# 3            203.50              2019                   A
# 4            203.50              2019                   A
# 5            203.50              2019                   A
# 6            203.50              2019                   A
# 7            203.50              2019                   A
# 8            203.50              2019                   A
# 9            203.50              2019                   A
# 10           203.50              2019                   A
# 11           203.50              2019                   A
# 12           203.50              2019                   A
# 13           203.50              2019                   A
# 14           203.50              2019                   A
# ...
