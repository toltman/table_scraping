# %%
import numpy as np
import pandas as pd
import re
import os
from table import Table

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
tabn = '204.27'
tab = Table('100tables/tabn' + tabn + '.xls', '2019')

# %%
tab.table_info
# Out:
#   digest_table_id digest_table_year digest_table_sub_id  \
# 0          204.27              2019                   A
#
#   digest_table_sub_title has_SE location_in year_in year       location  \
# 0                         FALSE       Title  Column       United States
#
#   Location_info                                        table_title headnote  \
# 0                English language learner (ELL) students enroll...
#
#                                            stub_head  \
# 0  Home language, grade, and selected student cha...
#
#                                         general_note  \
# 0  Includes all students identified as English la...
#
#                                          source_note  \
# 0  U.S. Department of Education, National Center ...
#
#                              last_prepared
# 0  This table was prepared September 2019.

# %%
tab.col_info
# Out:
#    digest_table_id digest_table_year digest_table_sub_id  \
# 0           204.27              2019                   A
# 1           204.27              2019                   A
# 2           204.27              2019                   A
# 3           204.27              2019                   A
# 4           204.27              2019                   A
# 5           204.27              2019                   A
# 6           204.27              2019                   A
# 7           204.27              2019                   A
# 8           204.27              2019                   A
# 9           204.27              2019                   A
# 10          204.27              2019                   A
# 11          204.27              2019                   A
# 12          204.27              2019                   A
# 13          204.27              2019                   A
# 14          204.27              2019                   A
# ...

# %%
tab.row_info
# Out:
#    digest_table_id digest_table_year digest_table_sub_id  \
# 4           204.27              2019                   A
# 5           204.27              2019                   A
# 6           204.27              2019                   A
# 7           204.27              2019                   A
# 8           204.27              2019                   A
# 9           204.27              2019                   A
# 10          204.27              2019                   A
# 11          204.27              2019                   A
# 12          204.27              2019                   A
# 13          204.27              2019                   A
# 14          204.27              2019                   A
# 15          204.27              2019                   A
# 16          204.27              2019                   A
# 17          204.27              2019                   A
# 18          204.27              2019                   A
# ...

# %%
tab.cell_info
# Out:
#     digest_table_id digest_table_year digest_table_sub_id  \
# 0            204.27              2019                   A
# 1            204.27              2019                   A
# 2            204.27              2019                   A
# 3            204.27              2019                   A
# 4            204.27              2019                   A
# 5            204.27              2019                   A
# 6            204.27              2019                   A
# 7            204.27              2019                   A
# 8            204.27              2019                   A
# 9            204.27              2019                   A
# 10           204.27              2019                   A
# 11           204.27              2019                   A
# 12           204.27              2019                   A
# 13           204.27              2019                   A
# 14           204.27              2019                   A
# ...

# %%
def lowest_level(row):
    location = ""
    row_levels = [f"row_level_{x}" for x in range(1,8)]
    for row_level in row_levels:
        if row[row_level] != "":
            location = row[row_level]
    return location

# %%
tab.row_info['location'] = tab.row_info.apply(lowest_level, axis=1)
