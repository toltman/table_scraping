# %%
import numpy as np
import pandas as pd
import re
import os
from table import Table

# %%
tables = {}

# %%
directory = "tables/"
for filename in os.listdir(directory):
    if filename.endswith(".xls"):
        file_directory = os.path.join(directory, filename)
        table = Table(file_directory, "2019")
        tables[table.number] = table

# %%
tables
# Out:
# {'203.10': <table.Table at 0x2803fae7c10>,
#  '203.50': <table.Table at 0x2803faf93d0>,
#  '204.10': <table.Table at 0x28041c123d0>,
#  '204.27': <table.Table at 0x2803eb1ae20>,
#  '213.10': <table.Table at 0x2803ea9d040>,
#  '215.10': <table.Table at 0x2803eb14070>,
#  '217.10': <table.Table at 0x28042099fd0>,
#  '217.15': <table.Table at 0x28042346fd0>,
#  '219.70': <table.Table at 0x280423466d0>,
#  '236.30': <table.Table at 0x280423eff70>,
#  '318.45': <table.Table at 0x280423af910>}

# %%
tables['203.10'].table_info.T
# Out:
#                    0                                                  1
# 0    digest_table_id                                             203.10
# 1  digest_table_year                                               2019
# 2        table_title  Enrollment in public elementary and secondary ...
# 3           headnote                                     [In thousands]
# 4          stub_head                                               Year
# 5       general_note  Due to changes in reporting and imputation pra...
# 6        source_note  U.S. Department of Education, National Center ...
# 7      last_prepared             This table was prepared December 2019.

# %%
tables['203.10'].col_info
# Out:
#    digest_table_id digest_table_year column_index column_level_1  \
# 0           203.10              2019            A     All grades
# 1           203.10              2019            B     Elementary
# 2           203.10              2019            C     Elementary
# 3           203.10              2019            D     Elementary
# 4           203.10              2019            E     Elementary
# 5           203.10              2019            F     Elementary
# 6           203.10              2019            G     Elementary
# 7           203.10              2019            H     Elementary
# 8           203.10              2019            I     Elementary
# 9           203.10              2019            J     Elementary
# 10          203.10              2019            K     Elementary
# 11          203.10              2019            L     Elementary
# 12          203.10              2019            M     Elementary
# ...

# %%
tables["203.50"].table_info.T
# Out:
#                    0                                                  1
# 0    digest_table_id                                             203.50
# 1  digest_table_year                                               2019
# 2        table_title  Enrollment and percentage distribution of enro...
# 3           headnote
# 4          stub_head                                    Region and year
# 5       general_note  Race categories exclude persons of Hispanic et...
# 6        source_note  U.S. Department of Education, National Center ...
# 7      last_prepared             This table was prepared December 2019.

# %%
tables["203.50"].col_info
# Out:
#    digest_table_id digest_table_year column_index             column_level_1  \
# 0           203.50              2019            A  Enrollment (in thousands)
# 1           203.50              2019            B  Enrollment (in thousands)
# 2           203.50              2019            C  Enrollment (in thousands)
# 3           203.50              2019            D  Enrollment (in thousands)
# 4           203.50              2019            E  Enrollment (in thousands)
# 5           203.50              2019            F  Enrollment (in thousands)
# 6           203.50              2019            G  Enrollment (in thousands)
# 7           203.50              2019            H  Enrollment (in thousands)
# 8           203.50              2019            I    Percentage distribution
# 9           203.50              2019            J    Percentage distribution
# 10          203.50              2019            K    Percentage distribution
# ...

# %%
tables["203.50"].raw_df
# Out:
#                                                    0   \
# 0   Table 203.50. Enrollment and percentage distri...
# 1                                     Region and year
# 2                                                 NaN
# 3                                                   1
# 4                                       United States
# ..                                                ...
# 75  \3\Includes imputations for prekindergarten en...
# 76  \4\Includes imputations for prekindergarten en...
# 77                                      \5\Projected.
# 78  NOTE: Race categories exclude persons of Hispa...
# 79  SOURCE: U.S. Department of Education, National...
#
#                            1      2      3           4      5    6   \
# 0                         NaN    NaN    NaN         NaN    NaN  NaN
# 1   Enrollment (in thousands)    NaN    NaN         NaN    NaN  NaN
# 2                       Total  White  Black  His- panic  Asian  NaN
# ...

# %%
tables["203.50"].raw_df.iloc[2,8].replace("\n", " ")
# Out:
# 'American Indian/ Alaska Native'

# %%
' '.join(tables["203.50"].raw_df.iloc[2,8].split())
# Out:
# 'American Indian/ Alaska Native'

# %%
tables["203.50"].raw_df.iloc[2,4].replace("- ", "")
# Out:
# 'Hispanic'

# %%
tables['203.10'].raw_df
# Out:
#                                                    0              1   \
# 0   Table 203.10. Enrollment in public elementary ...            NaN
# 1                                      [In thousands]            NaN
# 2                                                Year     All grades
# 3                                                 NaN            NaN
# 4                                                   1              2
# 5                                                1980        40877.5
# 6                                                1985          39422
# 7                                                1990        41216.7
# 8                                                1991        42046.9
# 9                                                1992        42823.3
# 10                                               1993        43464.9
# 11                                               1994        44111.5
# 12                                               1995        44840.5
# ...

# %%
tables['203.10'].raw_df.iloc[3,3].replace("-", "")
# Out:
# 'Prekindergarten'

# %%
tables['203.10'].raw_df.iloc[3,13].replace("- ", "")
# Out:
# 'Ungraded'
