# %%
import numpy as np
import pandas as pd
import re
import os
from table import Table

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
tabn = '215.10'
tab = Table('100tables/tabn' + tabn + '.xls', '2019')

# %%
tab.table_info
# Out:
#   digest_table_id digest_table_year digest_table_sub_id  \
# 0          215.10              2019                   A
#
#   digest_table_sub_title digest_table_sub_title_note has_SE location_in  \
# 0                                                     FALSE         Row
#
#   year_in year location location_info  \
# 0  Column
#
#                                          table_title headnote  \
# 0  Selected statistics on enrollment, teachers, d...
#
#           stub_head                                       general_note  \
# 0  Name of district  Total enrollment, staff, and teacher data in t...
#
#                                          source_note  \
# 0  U.S. Department of Education, National Center ...
#
#                          last_prepared
# 0  This table was prepared March 2020.

# %%
res = re.match(r".*([Ff]all \d{4}).*", "enrollment, fall 1999")
res
# Out:
# <re.Match object; span=(0, 21), match='enrollment, fall 1999'>

# %%
res.group(1)
# Out:
# 'fall 1999'

# %%
tab.col_info
# Out:
#    digest_table_id digest_table_year digest_table_sub_id  \
# 0           215.10              2019                   A
# 1           215.10              2019                   A
# 2           215.10              2019                   A
# 3           215.10              2019                   A
# 4           215.10              2019                   A
# 5           215.10              2019                   A
# 6           215.10              2019                   A
# 7           215.10              2019                   A
# 8           215.10              2019                   A
# 9           215.10              2019                   A
# 10          215.10              2019                   A
# 11          215.10              2019                   A
# 12          215.10              2019                   A
# 13          215.10              2019                   A
# 14          215.10              2019                   A
# ...

# %%
tab.row_info
# Out:
#     digest_table_id digest_table_year digest_table_sub_id  \
# 4            215.10              2019                   A
# 5            215.10              2019                   A
# 6            215.10              2019                   A
# 7            215.10              2019                   A
# 8            215.10              2019                   A
# 9            215.10              2019                   A
# 10           215.10              2019                   A
# 11           215.10              2019                   A
# 12           215.10              2019                   A
# 13           215.10              2019                   A
# 14           215.10              2019                   A
# 15           215.10              2019                   A
# 16           215.10              2019                   A
# 17           215.10              2019                   A
# 18           215.10              2019                   A
# ...

# %%
tab.cell_info
# Out:
#     digest_table_id digest_table_year digest_table_sub_id  \
# 0            215.10              2019                   A
# 1            215.10              2019                   A
# 2            215.10              2019                   A
# 3            215.10              2019                   A
# 4            215.10              2019                   A
# 5            215.10              2019                   A
# 6            215.10              2019                   A
# 7            215.10              2019                   A
# 8            215.10              2019                   A
# 9            215.10              2019                   A
# 10           215.10              2019                   A
# 11           215.10              2019                   A
# 12           215.10              2019                   A
# 13           215.10              2019                   A
# 14           215.10              2019                   A
# ...
