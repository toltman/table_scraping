# %%
import numpy as np
import pandas as pd
import re
import os
from table import Table

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
tab = Table("tables/tabn203.50.xls", "2019")

# %%
tab.raw_df
# Out:
#                                                    0   \
# 0   Table 203.50. Enrollment and percentage distri...
# 1                                     Region and year
# 2                                                 NaN
# 3                                                   1
# 4                                       United States
# 5                                                1995
# 6                                                2000
# 7                                                2001
# 8                                                2002
# 9                                                2003
# 10                                               2004
# 11                                               2005
# 12                                               2006
# 13                                               2007
# 14                                               2008
# 15                                               2009
# ...

# %%
tab.row_info
# Out:
#    digest_table_id digest_table_year digest_table_sub_id  \
# 5           203.50              2019                   A
# 6           203.50              2019                   A
# 7           203.50              2019                   A
# 8           203.50              2019                   A
# 9           203.50              2019                   A
# 10          203.50              2019                   A
# 11          203.50              2019                   A
# 12          203.50              2019                   A
# 13          203.50              2019                   A
# 14          203.50              2019                   A
# 15          203.50              2019                   A
# 16          203.50              2019                   A
# 17          203.50              2019                   A
# 18          203.50              2019                   A
# 19          203.50              2019                   A
# ...

# %%
tab.col_info
# Out:
#    digest_table_id digest_table_year column_index             column_level_1  \
# 0           203.50              2019            A  Enrollment (in thousands)
# 1           203.50              2019            B  Enrollment (in thousands)
# 2           203.50              2019            C  Enrollment (in thousands)
# 3           203.50              2019            D  Enrollment (in thousands)
# 4           203.50              2019            E  Enrollment (in thousands)
# 5           203.50              2019            F  Enrollment (in thousands)
# 6           203.50              2019            G  Enrollment (in thousands)
# 7           203.50              2019            H  Enrollment (in thousands)
# 8           203.50              2019            I    Percentage distribution
# 9           203.50              2019            J    Percentage distribution
# 10          203.50              2019            K    Percentage distribution
# ...

# %%
tab.row_info.loc[4,'E']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 4
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-ddf49743fe7e> in <module>
# ----> 1 tab.row_info.loc[4,'E']
#
# ...

# %%
row1 = tab.row_info.loc[4,:]
row2 = tab.row_info.loc[5,:]

# %%
row1.loc['A':].isna()

# %%
row1.loc['A':].str.match(r"^\s*$")

# %%
(row1.loc['A':].isna() | row1.loc['A':].str.match(r"^\s*$")).all()

# %%
(row2.loc['A':].isna() | row1.loc['A':].str.match(r"^\s*$")).all()

# %%
row2.loc['A':].isna() | row2.loc['A':].str.match(r"^\s*$")

# %%
row2
